# %% [markdown]
# **Useful Links:**
#
# 1. Deep Learning Book By Goodfellow :https://www.deeplearningbook.org/
# 2. Github link to repo : https://github.com/DebjitHore/PyTorchLearning
# 3. Alena Kruchkova YT DL Book Club: https://www.youtube.com/channel/UCF9O8Vj-FEbRDA5DcDGz-Pg/videos
